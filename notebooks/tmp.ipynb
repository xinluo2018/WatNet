# %%
import sys
import config
sys.path.append(config.root)
import os
import glob
import numpy as np
from utils.geotif_io import readTiff
from utils.imgShow import imgShow

# %%
paths_truth = sorted(glob.glob(config.root+'/data/dataset-s2/TraTruth/*'))

# %%
_,img = readTiff(paths_truth[0])
imgShow(img)
# Out:
# /Users/luo/miniconda3/envs/venv/lib/python3.6/site-packages/rasterio/__init__.py:207: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)

# %%
list_water, list_land = [], []
for path in paths_truth:
    _,img = readTiff(path)
    list_water.append(np.sum(img==1)) 
    list_land.append(np.sum(img==0))
# Out:
# /Users/luo/miniconda3/envs/venv/lib/python3.6/site-packages/rasterio/__init__.py:207: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)

# %%
num_land = np.sum(list_land)
num_land
# Out:
# 51033208
