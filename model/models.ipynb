# %%
# # mount on google drive
# from google.colab import drive
# drive.mount('/content/drive/')
# import os
# os.chdir("/content/drive/My Drive/Earth-surface-water-mapping")
# Out:
# Mounted at /content/drive/

# %%
# %%writefile models/models.py

try:
    get_ipython().magic(u'tensorflow_version 2.x')
except Exception:
    pass
import tensorflow as tf
from tensorflow.keras.layers import Lambda
import tensorflow.keras.backend as backend
import tensorflow.keras.layers as layers
import tensorflow.keras.models as models



##### MobileNetV2
relu6 = tf.keras.layers.ReLU(6.)
def _conv_block(inputs, filters, kernel, strides):
    x = tf.keras.layers.Conv2D(filters, kernel, padding='same', strides=strides)(inputs)
    x = tf.keras.layers.BatchNormalization()(x)
    return relu6(x)
def _bottleneck(inputs, filters, kernel, t, s, r=False):
    tchannel = inputs.shape[-1] * t
    x = _conv_block(inputs, tchannel, (1, 1), (1, 1))
    x = tf.keras.layers.DepthwiseConv2D(kernel, strides=(s, s), depth_multiplier=1, padding='same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = relu6(x)
    x = tf.keras.layers.Conv2D(filters, (1, 1), strides=(1, 1), padding='same')(x)  # 降维，改层为瓶颈层
    x = tf.keras.layers.BatchNormalization()(x)
    if r:
        x = tf.keras.layers.add([x, inputs])
    return x

def _inverted_residual_block(inputs, filters, kernel, t, strides, n):
    x = _bottleneck(inputs, filters, kernel, t, strides)
    for i in range(1, n):
        x = _bottleneck(x, filters, kernel, t, 1, True)
    return x

def MobileNetV2(input_shape, nclasses=2):
    """
    # Arguments
        input_shape: An integer or tuple/list of 3 integers, shape
            of input tensor.
        classes: Integer, number of classes.
    # Returns
        MobileNetv2 model.
    """

    inputs = tf.keras.layers.Input(shape=input_shape, name='input')
    x = _conv_block(inputs, 32, (3, 3), strides=(2, 2))   # 0.5*size         n_layers = 1
 
    x = _inverted_residual_block(x, 16, (3, 3), t=1, strides=1, n=1)  #        n_layers = 3
    x = _inverted_residual_block(x, 24, (3, 3), t=6, strides=2, n=2)  # 0.5*size,  n_layers = 6

    x = _inverted_residual_block(x, 32, (3, 3), t=6, strides=2, n=3)  # 0.5*size,  n_layers = 9
    x = _inverted_residual_block(x, 64, (3, 3), t=6, strides=2, n=4)  # 0.5*size,  n_layers = 12
    x = _inverted_residual_block(x, 96, (3, 3), t=6, strides=1, n=3)  #        n_layers = 9
    x = _inverted_residual_block(x, 160, (3, 3), t=6, strides=2, n=3)  # 0.5*size,  n_layers = 9
    x = _inverted_residual_block(x, 320, (3, 3), t=6, strides=1, n=1)  #        n_layers = 3

    x = _conv_block(x, 1280, (1, 1), strides=(1, 1))  # n_layers = 1
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Reshape((1, 1, 1280))(x)
    x = tf.keras.layers.Dropout(0.3, name='Dropout')(x)
    x = tf.keras.layers.Conv2D(nclasses, (1, 1), padding='same')(x)  # n_layers = 1
    x = tf.keras.layers.Activation('softmax', name='final_activation')(x)
    output = tf.keras.layers.Reshape((nclasses,), name='output')(x)
    model = tf.keras.models.Model(inputs, output)
    return model


##### Improved DeepLabV3+
def Upsample(tensor, size_1):  
    '''bilinear upsampling'''
    y = tf.image.resize(images=tensor, size=size_1)
    return y

def ASPP_2(tensor):

    '''atrous spatial pyramid pooling'''
    dims = backend.int_shape(tensor)
    y_pool = tf.keras.layers.AveragePooling2D(pool_size=(
        dims[1], dims[2]), name='average_pooling')(tensor)
    y_pool = tf.keras.layers.Conv2D(filters=128, kernel_size=1, padding='same',
                    kernel_initializer='he_normal', name='pool_1x1conv2d', use_bias=False)(y_pool)
    y_pool = tf.keras.layers.BatchNormalization(name=f'bn_1')(y_pool)
    y_pool = tf.keras.layers.Activation('relu', name=f'relu_1')(y_pool)
    y_pool = Upsample(tensor=y_pool, size_1=[dims[1], dims[2]])
    ## 1x1 conv
    y_1 = tf.keras.layers.Conv2D(filters=128, kernel_size=1, dilation_rate=1, padding='same',
                 kernel_initializer='he_normal', name='ASPP_conv2d_d1', use_bias=False)(tensor)
    y_1 = tf.keras.layers.BatchNormalization(name=f'bn_2')(y_1)
    y_1 = tf.keras.layers.Activation('relu', name=f'relu_2')(y_1)
    ## 3x3 dilated conv
    y_6 = tf.keras.layers.Conv2D(filters=128, kernel_size=3, dilation_rate=6, padding='same',
                 kernel_initializer='he_normal', name='ASPP_conv2d_d6', use_bias=False)(tensor)
    y_6 = tf.keras.layers.BatchNormalization(name=f'bn_3')(y_6)
    y_6 = tf.keras.layers.Activation('relu', name=f'relu_3')(y_6)
    ## 3x3 dilated conv
    y_12 = tf.keras.layers.Conv2D(filters=128, kernel_size=3, dilation_rate=12, padding='same',
                  kernel_initializer='he_normal', name='ASPP_conv2d_d12', use_bias=False)(tensor)
    y_12 = tf.keras.layers.BatchNormalization(name=f'bn_4')(y_12)
    y_12 = tf.keras.layers.Activation('relu', name=f'relu_4')(y_12)
    
    ## 3x3 dilated conv
    y_18 = tf.keras.layers.Conv2D(filters=128, kernel_size=3, dilation_rate=18, padding='same',
                  kernel_initializer='he_normal', name='ASPP_conv2d_d18', use_bias=False)(tensor)
    y_18 = tf.keras.layers.BatchNormalization(name=f'bn_5')(y_18)
    y_18 = tf.keras.layers.Activation('relu', name=f'relu_5')(y_18)
    
    ## concat
    y = tf.keras.layers.concatenate([y_pool, y_1, y_6, y_12, y_18], name='ASPP_concat')
    y = tf.keras.layers.Conv2D(filters=128, kernel_size=1, dilation_rate=1, padding='same',
               kernel_initializer='he_normal', name='ASPP_conv2d_final', use_bias=False)(y)
    y = tf.keras.layers.BatchNormalization(name=f'bn_final')(y)
    y = tf.keras.layers.Activation('relu', name=f'relu_final')(y)
    return y

def DeepLabV3Plus_improve(input_shape, base_model, d_feature, m_feature, l_feature, nclasses=2):
    '''
    Arguments:
        input_shape: (img_height, img_width, img_channel)
        base_model: backbone network
        d_feature, m_feature, l_feature: features corresponding 
                    to the deep, middle, and low layers of the backbone model
        nclass: number of classes.
    '''
    print('*** Building DeepLabv3Plus Network ***')
    (img_height, img_width, img_channel) = input_shape
    ## deep features
    base_model = base_model(input_shape, nclasses)
    image_features = base_model.get_layer(index = d_feature).output
    x_a = ASPP_2(image_features) 
    x_a = Upsample(tensor=x_a, size_1=[img_height // 4, img_width // 4])  
    ## middle features (1/4 patch size)
    x_b = base_model.get_layer(index = m_feature).output
    x_b = layers.Conv2D(filters=48, kernel_size=1, padding='same',
                 kernel_initializer='he_normal', name='low_level_projection', use_bias=False)(x_b)
    x_b = layers.BatchNormalization(name=f'bn_low_level_projection')(x_b)
    x_b = layers.Activation('relu', name='low_level_activation')(x_b)
    ## middle features (1/2 patch size)
    x_c = base_model.get_layer(index = l_feature).output
    x_c = layers.Conv2D(filters=48, kernel_size=1, padding='same',
                 kernel_initializer='he_normal', name='low_level_projection_2', use_bias=False)(x_c)
    x_c = layers.BatchNormalization(name=f'bn_low_level_projection_2')(x_c)
    x_c = layers.Activation('relu', name='low_level_activation_2')(x_c)
    ## concat
    x = layers.concatenate([x_a, x_b], name='decoder_concat_1')
    
    x = layers.Conv2D(filters=128, kernel_size=3, padding='same', activation='relu',
               kernel_initializer='he_normal', name='decoder_conv2d_1', use_bias=False)(x)
    x = layers.BatchNormalization(name=f'bn_decoder_1')(x)
    x = layers.Activation('relu', name='activation_decoder_1')(x)
    x = layers.Conv2D(filters=128, kernel_size=3, padding='same', activation='relu',
               kernel_initializer='he_normal', name='decoder_conv2d_2', use_bias=False)(x)
    x = layers.BatchNormalization(name=f'bn_decoder_2')(x)
    x = layers.Activation('relu', name='activation_decoder_2')(x)
    x = Upsample(x, [img_height//2, img_width//2])
    ## concat
    x_2 = layers.concatenate([x, x_c], name='decoder_concat_3')
    x_2 = layers.Conv2DTranspose(filters=128, kernel_size=3, strides=2, padding='same', 
               kernel_initializer='he_normal', name='decoder_deconv2d', use_bias=False)(x_2)
    x_2 = layers.BatchNormalization(name=f'bn_decoder_4')(x_2)
    x_2 = layers.Activation('relu', name='activation_decoder_4')(x_2)
    last = tf.keras.layers.Conv2D(1, (1,1),
                        strides=1,
                        padding='same',
                        kernel_initializer='he_normal',
                        activation= 'sigmoid')  ## (bs, 256, 256, 1)
    x_2 = last(x_2)
    model = models.Model(inputs=base_model.input, outputs=x_2, name='DeepLabV3_Plus_improve')
    print(f'*** Output_Shape => {model.output_shape} ***')
    return model
# Out:
# Writing models/models.py

# %%
## show the structured model
from models.models import MobileNetV2, DeepLabV3Plus_improve

model = DeepLabV3Plus_improve(input_shape=(512, 512, 6), base_model=MobileNetV2,  
                      d_feature=91, m_feature=24, l_feature=11, nclasses=2)
model.summary()
# Out:
# *** Building DeepLabv3Plus Network ***
# *** Output_Shape => (None, 512, 512, 1) ***
# Model: "DeepLabV3_Plus_improve"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 512, 512, 6) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 32) 1760        input[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 256, 256, 32) 128         conv2d[0][0]
# __________________________________________________________________________________________________
# re_lu (ReLU)                    multiple             0           batch_normalization[0][0]
#                                                                  batch_normalization_1[0][0]
#                                                                  batch_normalization_2[0][0]
#                                                                  batch_normalization_4[0][0]
#                                                                  batch_normalization_5[0][0]
#                                                                  batch_normalization_7[0][0]
#                                                                  batch_normalization_8[0][0]
#                                                                  batch_normalization_10[0][0]
#                                                                  batch_normalization_11[0][0]
#                                                                  batch_normalization_13[0][0]
#                                                                  batch_normalization_14[0][0]
#                                                                  batch_normalization_16[0][0]
#                                                                  batch_normalization_17[0][0]
#                                                                  batch_normalization_19[0][0]
#                                                                  batch_normalization_20[0][0]
#                                                                  batch_normalization_22[0][0]
#                                                                  batch_normalization_23[0][0]
#                                                                  batch_normalization_25[0][0]
#                                                                  batch_normalization_26[0][0]
#                                                                  batch_normalization_28[0][0]
#                                                                  batch_normalization_29[0][0]
#                                                                  batch_normalization_31[0][0]
#                                                                  batch_normalization_32[0][0]
#                                                                  batch_normalization_34[0][0]
#                                                                  batch_normalization_35[0][0]
#                                                                  batch_normalization_37[0][0]
#                                                                  batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 32) 1056        re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 256, 256, 32) 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d (DepthwiseConv (None, 256, 256, 32) 320         re_lu[1][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 256, 256, 32) 128         depthwise_conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 256, 256, 16) 528         re_lu[2][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 256, 256, 16) 64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 256, 256, 96) 1632        batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 256, 256, 96) 384         conv2d_3[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_1 (DepthwiseCo (None, 128, 128, 96) 960         re_lu[3][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 128, 128, 96) 384         depthwise_conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 128, 128, 24) 2328        re_lu[4][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 128, 128, 24) 96          conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 128, 128, 144 3600        batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 128, 128, 144 576         conv2d_5[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2 (DepthwiseCo (None, 128, 128, 144 1440        re_lu[5][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 128, 128, 144 576         depthwise_conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 128, 128, 24) 3480        re_lu[6][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 128, 128, 24) 96          conv2d_6[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 128, 128, 24) 0           batch_normalization_9[0][0]
#                                                                  batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 128, 128, 144 3600        add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 128, 128, 144 576         conv2d_7[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_3 (DepthwiseCo (None, 64, 64, 144)  1440        re_lu[7][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 64, 64, 144)  576         depthwise_conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 64, 64, 32)   4640        re_lu[8][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 64, 64, 32)   128         conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 64, 64, 192)  6336        batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 64, 64, 192)  768         conv2d_9[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_4 (DepthwiseCo (None, 64, 64, 192)  1920        re_lu[9][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 64, 64, 192)  768         depthwise_conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 64, 64, 32)   6176        re_lu[10][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 64, 64, 32)   128         conv2d_10[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 64, 64, 32)   0           batch_normalization_15[0][0]
#                                                                  batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 64, 64, 192)  6336        add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 64, 64, 192)  768         conv2d_11[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_5 (DepthwiseCo (None, 64, 64, 192)  1920        re_lu[11][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 64, 64, 192)  768         depthwise_conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 64, 64, 32)   6176        re_lu[12][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 64, 64, 32)   128         conv2d_12[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 64, 64, 32)   0           batch_normalization_18[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 64, 192)  6336        add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 64, 64, 192)  768         conv2d_13[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_6 (DepthwiseCo (None, 32, 32, 192)  1920        re_lu[13][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 32, 32, 192)  768         depthwise_conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 32, 32, 64)   12352       re_lu[14][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 32, 32, 64)   256         conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 32, 32, 384)  24960       batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 32, 32, 384)  1536        conv2d_15[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_7 (DepthwiseCo (None, 32, 32, 384)  3840        re_lu[15][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 32, 32, 384)  1536        depthwise_conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 32, 32, 64)   24640       re_lu[16][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 32, 32, 64)   256         conv2d_16[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 32, 32, 64)   0           batch_normalization_24[0][0]
#                                                                  batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 32, 32, 384)  24960       add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 32, 32, 384)  1536        conv2d_17[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_8 (DepthwiseCo (None, 32, 32, 384)  3840        re_lu[17][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 32, 32, 384)  1536        depthwise_conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 32, 32, 64)   24640       re_lu[18][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 32, 32, 64)   256         conv2d_18[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 32, 32, 64)   0           batch_normalization_27[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 32, 32, 384)  24960       add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 32, 32, 384)  1536        conv2d_19[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_9 (DepthwiseCo (None, 32, 32, 384)  3840        re_lu[19][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 32, 32, 384)  1536        depthwise_conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 32, 32, 64)   24640       re_lu[20][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 32, 32, 64)   256         conv2d_20[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 32, 32, 64)   0           batch_normalization_30[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 32, 32, 384)  24960       add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 32, 32, 384)  1536        conv2d_21[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_10 (DepthwiseC (None, 32, 32, 384)  3840        re_lu[21][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 32, 32, 384)  1536        depthwise_conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 32, 32, 96)   36960       re_lu[22][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 32, 32, 96)   384         conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 32, 32, 576)  55872       batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 32, 32, 576)  2304        conv2d_23[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_11 (DepthwiseC (None, 32, 32, 576)  5760        re_lu[23][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 32, 32, 576)  2304        depthwise_conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 32, 32, 96)   55392       re_lu[24][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 32, 32, 96)   384         conv2d_24[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 32, 32, 96)   0           batch_normalization_36[0][0]
#                                                                  batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 32, 32, 576)  55872       add_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 32, 32, 576)  2304        conv2d_25[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_12 (DepthwiseC (None, 32, 32, 576)  5760        re_lu[25][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 32, 32, 576)  2304        depthwise_conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 32, 32, 96)   55392       re_lu[26][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 32, 32, 96)   384         conv2d_26[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 32, 32, 96)   0           batch_normalization_39[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 32, 32, 576)  55872       add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 32, 32, 576)  2304        conv2d_27[0][0]
# __________________________________________________________________________________________________
# average_pooling (AveragePooling (None, 1, 1, 576)    0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# pool_1x1conv2d (Conv2D)         (None, 1, 1, 128)    73728       average_pooling[0][0]
# __________________________________________________________________________________________________
# bn_1 (BatchNormalization)       (None, 1, 1, 128)    512         pool_1x1conv2d[0][0]
# __________________________________________________________________________________________________
# ASPP_conv2d_d1 (Conv2D)         (None, 32, 32, 128)  73728       batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# ASPP_conv2d_d6 (Conv2D)         (None, 32, 32, 128)  663552      batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# ASPP_conv2d_d12 (Conv2D)        (None, 32, 32, 128)  663552      batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# ASPP_conv2d_d18 (Conv2D)        (None, 32, 32, 128)  663552      batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# relu_1 (Activation)             (None, 1, 1, 128)    0           bn_1[0][0]
# __________________________________________________________________________________________________
# bn_2 (BatchNormalization)       (None, 32, 32, 128)  512         ASPP_conv2d_d1[0][0]
# __________________________________________________________________________________________________
# bn_3 (BatchNormalization)       (None, 32, 32, 128)  512         ASPP_conv2d_d6[0][0]
# __________________________________________________________________________________________________
# bn_4 (BatchNormalization)       (None, 32, 32, 128)  512         ASPP_conv2d_d12[0][0]
# __________________________________________________________________________________________________
# bn_5 (BatchNormalization)       (None, 32, 32, 128)  512         ASPP_conv2d_d18[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ResizeBilinear (Ten [(None, 32, 32, 128) 0           relu_1[0][0]
# __________________________________________________________________________________________________
# relu_2 (Activation)             (None, 32, 32, 128)  0           bn_2[0][0]
# __________________________________________________________________________________________________
# relu_3 (Activation)             (None, 32, 32, 128)  0           bn_3[0][0]
# __________________________________________________________________________________________________
# relu_4 (Activation)             (None, 32, 32, 128)  0           bn_4[0][0]
# __________________________________________________________________________________________________
# relu_5 (Activation)             (None, 32, 32, 128)  0           bn_5[0][0]
# __________________________________________________________________________________________________
# ASPP_concat (Concatenate)       (None, 32, 32, 640)  0           tf_op_layer_ResizeBilinear[0][0]
#                                                                  relu_2[0][0]
#                                                                  relu_3[0][0]
#                                                                  relu_4[0][0]
#                                                                  relu_5[0][0]
# __________________________________________________________________________________________________
# ASPP_conv2d_final (Conv2D)      (None, 32, 32, 128)  81920       ASPP_concat[0][0]
# __________________________________________________________________________________________________
# bn_final (BatchNormalization)   (None, 32, 32, 128)  512         ASPP_conv2d_final[0][0]
# __________________________________________________________________________________________________
# low_level_projection (Conv2D)   (None, 128, 128, 48) 6912        batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# relu_final (Activation)         (None, 32, 32, 128)  0           bn_final[0][0]
# __________________________________________________________________________________________________
# bn_low_level_projection (BatchN (None, 128, 128, 48) 192         low_level_projection[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ResizeBilinear_1 (T [(None, 128, 128, 12 0           relu_final[0][0]
# __________________________________________________________________________________________________
# low_level_activation (Activatio (None, 128, 128, 48) 0           bn_low_level_projection[0][0]
# __________________________________________________________________________________________________
# decoder_concat_1 (Concatenate)  (None, 128, 128, 176 0           tf_op_layer_ResizeBilinear_1[0][0
#                                                                  low_level_activation[0][0]
# __________________________________________________________________________________________________
# decoder_conv2d_1 (Conv2D)       (None, 128, 128, 128 202752      decoder_concat_1[0][0]
# __________________________________________________________________________________________________
# bn_decoder_1 (BatchNormalizatio (None, 128, 128, 128 512         decoder_conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_decoder_1 (Activatio (None, 128, 128, 128 0           bn_decoder_1[0][0]
# __________________________________________________________________________________________________
# decoder_conv2d_2 (Conv2D)       (None, 128, 128, 128 147456      activation_decoder_1[0][0]
# __________________________________________________________________________________________________
# bn_decoder_2 (BatchNormalizatio (None, 128, 128, 128 512         decoder_conv2d_2[0][0]
# __________________________________________________________________________________________________
# low_level_projection_2 (Conv2D) (None, 256, 256, 48) 4608        batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# activation_decoder_2 (Activatio (None, 128, 128, 128 0           bn_decoder_2[0][0]
# __________________________________________________________________________________________________
# bn_low_level_projection_2 (Batc (None, 256, 256, 48) 192         low_level_projection_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ResizeBilinear_2 (T [(None, 256, 256, 12 0           activation_decoder_2[0][0]
# __________________________________________________________________________________________________
# low_level_activation_2 (Activat (None, 256, 256, 48) 0           bn_low_level_projection_2[0][0]
# __________________________________________________________________________________________________
# decoder_concat_3 (Concatenate)  (None, 256, 256, 176 0           tf_op_layer_ResizeBilinear_2[0][0
#                                                                  low_level_activation_2[0][0]
# __________________________________________________________________________________________________
# decoder_deconv2d (Conv2DTranspo (None, 512, 512, 128 202752      decoder_concat_3[0][0]
# __________________________________________________________________________________________________
# bn_decoder_4 (BatchNormalizatio (None, 512, 512, 128 512         decoder_deconv2d[0][0]
# __________________________________________________________________________________________________
# activation_decoder_4 (Activatio (None, 512, 512, 128 0           bn_decoder_4[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 512, 512, 1)  129         activation_decoder_4[0][0]
# ==================================================================================================
# Total params: 3,416,577
# Trainable params: 3,396,737
# Non-trainable params: 19,840
# __________________________________________________________________________________________________
